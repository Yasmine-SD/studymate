# %%
# !pip install transformers datasets torch -q

# %%
import pandas as pd

data = [
    {"input": "What is machine learning?",
     "output": "Great question! Machine learning means teaching a computer to learn from data instead of programming every rule manually. For example, instead of writing rules to detect spam, we show the model 1000 spam emails and it learns the patterns itself. Does that make sense? Want to go deeper?"},

    {"input": "I don't understand supervised learning.",
     "output": "No worries! In supervised learning, we give the model labeled examples — like showing it photos of cats and dogs WITH the correct labels. It learns the difference step by step. Think of it like studying with an answer key. Shall we look at a concrete example together?"},

    {"input": "What is unsupervised learning?",
     "output": "Good question! Unsupervised learning means the model gets data with NO labels. It finds patterns on its own. Imagine giving someone 1000 news articles with no categories — they'd naturally group similar ones together. That's clustering, one type of unsupervised learning. Want to explore more types?"},

    {"input": "Explain overfitting simply.",
     "output": "Sure! Imagine memorizing every answer in a practice exam without understanding. You'd ace that exam but fail a new one. That's overfitting — the model memorizes training data but fails on new data. Does this analogy help? Want to know how to fix it?"},

    {"input": "What is underfitting?",
     "output": "Great question! Underfitting is the opposite of overfitting. The model is too simple — it doesn't even learn the training data well. Like studying only one page for an exam that covers 10 chapters. Shall we see how to detect it?"},

    {"input": "What is deep learning?",
     "output": "Nice question! Deep learning is a type of machine learning using neural networks with many layers. Each layer learns something more complex — first edges, then shapes, then full objects. It's why your phone recognizes faces! Want to understand the layers better?"},

    {"input": "Can you teach me neural networks?",
     "output": "Of course! A neural network is inspired by the human brain. It has neurons organized in layers. The first layer receives raw data, the middle layers find patterns, and the last layer gives the prediction. Think of it as a factory with multiple departments. Shall we zoom into one layer?"},

    {"input": "What is backpropagation?",
     "output": "Good question — this one is key! After the model makes a prediction, we check how wrong it was. Backpropagation sends that error backwards through the network to adjust the weights. Like correcting your mistakes after a quiz and improving for next time. Want to see the math behind it?"},

    {"input": "Explain activation functions simply.",
     "output": "Sure! Activation functions decide whether a neuron fires or not — they add non-linearity to the network. Without them, no matter how many layers you have, the model stays linear. The most popular one is ReLU: if input is positive, keep it; if negative, output 0. Shall we compare a few?"},

    {"input": "What is a large language model?",
     "output": "Excellent question! A Large Language Model (LLM) is a model trained on massive amounts of text to understand and generate human language. GPT, Claude, Gemini — these are all LLMs. They predict the next word, over and over, to generate coherent text. Want to understand how they're trained?"},

    {"input": "Explain transformers simply.",
     "output": "Sure! The Transformer is the architecture behind modern LLMs. Its key innovation is the attention mechanism — the model looks at ALL words in a sentence simultaneously and decides which ones matter most. Way faster than older methods. Shall we look at attention together?"},

    {"input": "What is fine-tuning?",
     "output": "Great question! Fine-tuning means taking a pretrained model and training it further on a specific dataset. Instead of starting from scratch, you adapt an already smart model to your task. Like hiring an expert and giving them specific training for your company. Want to see how it works in practice?"},

    {"input": "I don't understand attention mechanism.",
     "output": "No problem, let's take it slow! Attention lets the model focus on the most relevant words when processing a sentence. For example, in 'The cat sat on the mat because it was tired' — when understanding 'it', the model attends strongly to 'cat'. Does that help? Want a visual explanation?"},

    {"input": "What is gradient descent?",
     "output": "Great analogy coming up! Imagine you're on a mountain blindfolded trying to reach the bottom. You feel the slope around you and take a small step downhill. Then repeat. That's gradient descent — we minimize the loss function step by step. The step size is called the learning rate. Shall we explore that next?"},

    {"input": "Explain loss function simply.",
     "output": "Sure! A loss function measures how wrong the model's predictions are. If the model predicts 9 but the answer is 10, the loss is small. If it predicts 100, the loss is huge. The goal of training is to minimize this loss. Think of it as your exam score in reverse — lower is better. Want to see common examples?"},

    {"input": "What is a decision tree?",
     "output": "Nice topic! A decision tree makes predictions by asking a series of yes/no questions. Like a flowchart — is the email from an unknown sender? Yes → is there a link? Yes → Spam. Each split tries to separate the data best. Very visual and easy to interpret. Want to see how it splits the data?"},

    {"input": "What is random forest?",
     "output": "Great question! Random Forest builds many decision trees, each trained on a random subset of data and features. Then it takes the majority vote. It's like asking 100 doctors for a diagnosis instead of one — more reliable! This is called ensemble learning. Want to understand why it reduces overfitting?"},

    {"input": "What is reinforcement learning?",
     "output": "Great question! In reinforcement learning, an agent learns by trial and error — it takes actions, gets rewards or penalties, and improves over time. Like training a dog with treats. AlphaGo and ChatGPT both use this approach. Want to understand the reward system better?"},

    {"input": "What is transfer learning?",
     "output": "Excellent question! Transfer learning means taking a model already trained on a large dataset and reusing it for your specific task. Instead of starting from zero, you start from a smart base. Like hiring someone with 10 years experience instead of a fresh graduate. Want to see a practical example?"},

    {"input": "What is data preprocessing?",
     "output": "Good question! Data preprocessing is cleaning and preparing raw data before training. This includes handling missing values, removing duplicates, encoding categories, and scaling numbers. Garbage in = garbage out — clean data is everything. Want to go through each step?"},
]

df = pd.DataFrame(data)
print(f"Dataset size: {len(df)} examples")
# Out:
# Dataset size: 20 examples

# %%
extra_data = [
    {"input": "What is a training set?",
     "output": "Good question! A training set is the data we use to teach the model. Think of it like your textbook — the model studies it to learn patterns. The more diverse and clean your training data, the better the model learns. Want to know about test sets too?"},

    {"input": "What is a test set?",
     "output": "Great follow-up! A test set is data the model has never seen during training. We use it to check if the model really learned or just memorized. Like a final exam with new questions. Does that distinction make sense?"},

    {"input": "What is a label in machine learning?",
     "output": "Nice question! A label is the correct answer for a data point. For example, an email labeled 'spam' or 'not spam'. The model learns to predict these labels from the input data. Want to see how labels are used in training?"},

    {"input": "What is feature engineering?",
     "output": "Good question! Feature engineering means creating or selecting the most useful inputs for your model. For example, from a date you might extract 'day of week' or 'is weekend' — these are more useful than the raw date. It's one of the most impactful skills in ML. Shall we look at examples?"},

    {"input": "What is bias in machine learning?",
     "output": "Important topic! Bias in ML means the model makes systematic errors — it consistently gets certain things wrong. For example, a hiring model trained on historical data might be biased against certain groups. Detecting and reducing bias is crucial. Want to explore types of bias?"},

    {"input": "What is a epoch in deep learning?",
     "output": "Great question! One epoch means the model has seen the entire training dataset once. If you have 1000 examples and train for 10 epochs, the model sees each example 10 times. More epochs = more learning, but too many can cause overfitting. Does that make sense?"},

    {"input": "What is a batch size?",
     "output": "Good question! Instead of feeding all data at once, we split it into small batches. Batch size is how many examples the model sees before updating its weights. Small batches = slower but more stable learning. Large batches = faster but needs more memory. Want to know how to choose it?"},

    {"input": "What is dropout in neural networks?",
     "output": "Nice topic! Dropout is a technique to prevent overfitting. During training, we randomly turn off some neurons — force the network to not rely on any single neuron too much. It's like studying in a noisy environment so you can focus anywhere. Want to see how it's implemented?"},

    {"input": "What is transfer learning?",
     "output": "Excellent question! Transfer learning means taking a model already trained on a large dataset and reusing it for your specific task. Instead of starting from zero, you start from a smart base. Like hiring someone with 10 years experience instead of a fresh graduate. Want to see a practical example?"},

    {"input": "What is a recurrent neural network?",
     "output": "Good question! An RNN is designed for sequential data — text, time series, speech. Unlike regular networks, it has memory: the output of one step feeds into the next. Think of reading a sentence word by word and remembering the context. Want to compare it with transformers?"},

    {"input": "What is a prompt in AI?",
     "output": "Great question! A prompt is the input you give to an AI model — your instruction or question. The quality of your prompt directly affects the quality of the response. This is why prompt engineering is now a real skill. Want to learn some prompting techniques?"},

    {"input": "What is tokenization?",
     "output": "Nice question! Tokenization is splitting text into smaller units called tokens. For example 'I love AI' becomes ['I', 'love', 'AI']. Models don't read raw text — they read token IDs. The vocabulary size determines how many unique tokens a model knows. Shall we see how it works in practice?"},

    {"input": "What is the difference between GPT and BERT?",
     "output": "Good comparison! GPT is a decoder model — it generates text from left to right, great for chatbots and text generation. BERT is an encoder model — it reads the full sentence at once, great for classification and understanding. Think of GPT as a writer and BERT as a reader. Want to go deeper?"},

    {"input": "What is hallucination in LLMs?",
     "output": "Important concept! Hallucination is when an LLM confidently generates false information. For example, inventing a fake research paper with real-sounding authors. It happens because the model predicts plausible text, not verified facts. This is why human verification is still essential. Want to know how to reduce it?"},

    {"input": "What is RAG?",
     "output": "Great question! RAG stands for Retrieval Augmented Generation. Instead of relying only on what the model learned during training, we first retrieve relevant documents and feed them to the model as context. Like giving an open-book exam instead of closed-book. Want to see how it works?"},

    {"input": "What is data preprocessing?",
     "output": "Good question! Data preprocessing is cleaning and preparing raw data before training. This includes handling missing values, removing duplicates, encoding categories, and scaling numbers. Garbage in = garbage out — clean data is everything. Want to go through each step?"},

    {"input": "What is normalization?",
     "output": "Nice question! Normalization scales your data to a range like 0 to 1. For example, if ages range from 0 to 100, after normalization they range from 0 to 1. This helps the model treat all features equally — without it, large numbers dominate. Want to see the formula?"},

    {"input": "What is the difference between classification and regression?",
     "output": "Good question! Classification predicts a category — spam or not spam, cat or dog. Regression predicts a number — house price, temperature tomorrow. Both are supervised learning but with different output types. Want to see examples of algorithms for each?"},

    {"input": "What is clustering?",
     "output": "Great topic! Clustering groups similar data points together without labels. For example, grouping customers by buying behavior — without telling the model what the groups are. K-means is the most popular algorithm. Want to understand how it finds the groups?"},

    {"input": "What is dimensionality reduction?",
     "output": "Good question! When you have too many features, dimensionality reduction compresses them into fewer dimensions while keeping the important information. PCA is the classic method. Think of it like summarizing a 100-page report into 1 page. Want to see how PCA works?"},

    {"input": "What is explainability in AI?",
     "output": "Important topic! Explainability means being able to understand why a model made a decision. A doctor can't just say 'the AI said so' — they need to know why. Techniques like SHAP and LIME help explain model predictions. Want to explore one of them?"},

    {"input": "What is the difference between AI and ML?",
     "output": "Good distinction! AI is the broad field of making machines intelligent. ML is a subset of AI that focuses on learning from data. Think of AI as the goal and ML as one of the methods to achieve it. Deep learning is then a subset of ML. Does that hierarchy make sense?"},

    {"input": "What is reinforcement learning?",
     "output": "Great question! In reinforcement learning, an agent learns by trial and error — it takes actions, gets rewards or penalties, and improves over time. Like training a dog with treats. AlphaGo and ChatGPT's RLHF both use this approach. Want to understand the reward system better?"},

    {"input": "What is a confusion matrix?",
     "output": "Nice topic! A confusion matrix shows the performance of a classification model. It compares predicted vs actual labels — true positives, false positives, true negatives, false negatives. From it we calculate accuracy, precision, and recall. Want to walk through an example?"},

    {"input": "What is precision and recall?",
     "output": "Good question! Precision = out of all positive predictions, how many were correct. Recall = out of all actual positives, how many did we catch. There's always a tradeoff — a spam filter with high recall catches more spam but also more legitimate emails. Want to see the formulas?"},

    {"input": "What is a GAN?",
     "output": "Fascinating topic! A GAN has two networks — a Generator that creates fake data and a Discriminator that tries to detect fakes. They compete until the generator makes data so realistic the discriminator can't tell. This is how AI generates realistic images and deepfakes. Want to go deeper?"},

    {"input": "What is an autoencoder?",
     "output": "Good question! An autoencoder compresses data into a smaller representation then reconstructs it. The middle compressed layer captures the essential features. Used for anomaly detection, denoising images, and data compression. Want to see the architecture?"},

    {"input": "What is the vanishing gradient problem?",
     "output": "Important concept! In deep networks, gradients get smaller and smaller as they travel backwards through layers. Eventually the early layers learn almost nothing. This is why very deep networks were hard to train before ReLU and residual connections. Shall we look at the solutions?"},

    {"input": "What is a learning rate?",
     "output": "Great question! The learning rate controls how big each step is during gradient descent. Too high = the model jumps around and never converges. Too low = the model learns very slowly. Finding the right learning rate is one of the most important hyperparameters to tune. Want to see strategies?"},

    {"input": "What is batch normalization?",
     "output": "Good question! Batch normalization normalizes the inputs of each layer during training. This stabilizes learning, allows higher learning rates, and reduces sensitivity to initialization. It's now standard in most deep learning architectures. Want to understand where to place it in a network?"},

    {"input": "What is RLHF?",
     "output": "Great topic! RLHF stands for Reinforcement Learning from Human Feedback. Humans rank model outputs from best to worst, training a reward model. Then the LLM is fine-tuned to maximize this reward. This is how ChatGPT was made helpful and safe. Want to understand each step?"},

    {"input": "What is a vector embedding?",
     "output": "Nice question! An embedding converts text into a list of numbers — a vector. Similar words end up with similar vectors. For example, 'king' and 'queen' are close in vector space. This lets models do math with meaning. Want to see how embeddings are used in practice?"},

    {"input": "What is semantic search?",
     "output": "Good question! Semantic search finds results by meaning, not just keywords. Instead of matching exact words, it compares vector embeddings. So searching 'happy' might return results about 'joy' or 'cheerful'. It powers modern search engines and RAG systems. Want to see how it's built?"},

    {"input": "What is prompt engineering?",
     "output": "Excellent topic! Prompt engineering is crafting inputs to get the best outputs from an LLM. Techniques include giving examples, specifying format, adding context, and using chain-of-thought. A well-engineered prompt can dramatically improve results without any training. Want to learn the key techniques?"},

    {"input": "What is the context window?",
     "output": "Good question! The context window is the maximum amount of text an LLM can process at once. GPT-4 has 128k tokens, Claude has up to 200k. If your text exceeds the window, earlier parts get cut off. This is why RAG is useful for long documents. Want to understand the implications?"},

    {"input": "How do I evaluate a machine learning model?",
     "output": "Great practical question! It depends on the task. For classification: accuracy, precision, recall, F1 score. For regression: MAE, MSE, RMSE. For language models: perplexity, BLEU score. Always evaluate on data the model has never seen. Want to go through each metric?"},

    {"input": "What is the difference between parameters and hyperparameters?",
     "output": "Important distinction! Parameters are learned during training — like weights in a neural network. Hyperparameters are set before training — like learning rate, batch size, number of layers. You tune hyperparameters, the model learns parameters. Does that difference make sense?"},

    {"input": "What is early stopping?",
     "output": "Good question! Early stopping monitors validation loss during training and stops when it starts increasing — before overfitting kicks in. Instead of training for a fixed number of epochs, you stop at the optimal point. It's a simple but very effective regularization technique. Want to see how to implement it?"},

    {"input": "What is data augmentation?",
     "output": "Nice topic! Data augmentation creates new training examples by modifying existing ones. For images: rotate, flip, crop, change brightness. For text: synonym replacement, back-translation. It artificially increases dataset size and reduces overfitting. Want to see practical examples?"},

    {"input": "What is the difference between a parameter and a weight?",
     "output": "Good question! In neural networks, weights and parameters are often used interchangeably. Technically, parameters include both weights (connections between neurons) and biases (offset values). Both are learned during training via backpropagation. Want to see how they're initialized?"},
]

extra_df = pd.DataFrame(extra_data)
df = pd.concat([df, extra_df], ignore_index=True)
print(f"Total examples after extra: {len(df)}")
# Out:
# Total examples after extra: 60

# %%
follow_up_data = [
    # Machine Learning
    {"input": "Can you explain more about machine learning?",
     "output": "Sure! Going deeper — machine learning has three main types. Supervised learning uses labeled data (spam detection, image classification). Unsupervised learning finds patterns with no labels (clustering customers). Reinforcement learning learns by trial and error (game playing, robotics). Each solves different problems. Want to explore one type in detail?"},

    {"input": "Tell me more about supervised learning.",
     "output": "Great! Let's go deeper. In supervised learning, you have input X and label Y. The model learns a function f(X) = Y. For example: X = email content, Y = spam/not spam. You train on thousands of examples, then test on new ones. Common algorithms: linear regression, decision trees, neural networks. Want to see a concrete example?"},

    {"input": "Can you explain more about unsupervised learning?",
     "output": "Of course! In unsupervised learning there are no labels — the model discovers structure on its own. The most common technique is clustering: grouping similar data points together. K-means is the classic algorithm. Another technique is dimensionality reduction like PCA — compressing data while keeping key information. Want to explore clustering in detail?"},

    {"input": "Tell me more about overfitting.",
     "output": "Absolutely! Overfitting happens when your model memorizes training data instead of learning patterns. Signs: high training accuracy but low test accuracy. Solutions include: getting more training data, using dropout in neural networks, applying L2 regularization, simplifying the model architecture, or using early stopping. The key is finding the right balance between complexity and generalization. Want to explore one solution?"},

    {"input": "Can you explain more about underfitting?",
     "output": "Sure! Underfitting means your model is too simple to capture the patterns. Signs: low accuracy on both training AND test data. Solutions: use a more complex model, add more features, train for more epochs, reduce regularization. Think of it as needing a more powerful tool for the job. Does that help? Want to compare it with overfitting?"},

    # Deep Learning
    {"input": "Can you explain more about deep learning?",
     "output": "Great! Deep learning uses neural networks with many layers — that's what 'deep' means. Each layer learns increasingly abstract features. Layer 1: detects edges. Layer 2: detects shapes. Layer 3: detects objects. This hierarchy is why deep learning excels at images, speech, and text. The more layers, the more complex patterns it can learn. Want to explore a specific architecture?"},

    {"input": "Tell me more about neural networks.",
     "output": "Of course! Let's go deeper. Each neuron computes: output = activation(weights × inputs + bias). The weights are what the model learns during training. Common activation functions: ReLU (max(0,x)), sigmoid (for binary output), softmax (for multi-class). The network learns by adjusting weights to minimize the loss function via backpropagation. Want to understand backpropagation step by step?"},

    {"input": "Can you explain more about backpropagation?",
     "output": "Absolutely! Backpropagation works in 4 steps. Step 1: forward pass — compute predictions. Step 2: compute loss — measure how wrong we are. Step 3: backward pass — compute gradient of loss with respect to each weight using chain rule. Step 4: update weights — subtract gradient × learning rate. Repeat until loss is minimized. It's essentially calculus applied to neural networks. Want to see the math?"},

    {"input": "Tell me more about activation functions.",
     "output": "Sure! The three most important activation functions are: ReLU (f(x) = max(0,x)) — used in hidden layers, fast and effective. Sigmoid (f(x) = 1/(1+e^-x)) — outputs 0 to 1, used for binary classification. Softmax — outputs probabilities summing to 1, used for multi-class output. Without activation functions, no matter how many layers you stack, the network behaves like a single linear function. Does that clarify things?"},

    {"input": "Can you explain more about CNNs?",
     "output": "Great! A CNN has three key layer types. Convolutional layers: apply filters to detect local patterns like edges and textures. Pooling layers: reduce spatial dimensions, keeping important features. Fully connected layers: combine features for final prediction. CNNs are translation invariant — they detect a cat whether it's in the top-left or bottom-right of the image. This is why they dominate computer vision. Want to understand how the filters learn?"},

    # LLMs
    {"input": "Can you explain more about large language models?",
     "output": "Of course! LLMs are trained on hundreds of billions of words from the internet, books, and code. They learn by predicting the next token — given 'The cat sat on the', predict 'mat'. This simple objective at massive scale creates models that can reason, write, and code. GPT-4 has around 1 trillion parameters. Training costs millions of dollars. Want to understand the transformer architecture behind them?"},

    {"input": "Tell me more about transformers.",
     "output": "Absolutely! The Transformer has two key components. The encoder reads the full input sequence and builds a rich representation. The decoder generates the output token by token. The key innovation is multi-head attention — it runs attention multiple times in parallel, each head focusing on different relationships. Add positional encoding (since there's no recurrence) and you have the full architecture. Want to dive into multi-head attention?"},

    {"input": "Can you explain more about attention mechanism?",
     "output": "Sure! Attention computes three vectors for each token: Query (what am I looking for?), Key (what do I contain?), Value (what do I return?). Attention score = softmax(Q × K^T / sqrt(d)) × V. In plain English: each token asks a question, compares with all other tokens, and builds a weighted summary. This lets the model capture long-range dependencies that RNNs struggled with. Does that make sense?"},

    {"input": "Tell me more about fine-tuning.",
     "output": "Great! Fine-tuning has several variants. Full fine-tuning: update all weights — expensive but powerful. LoRA: add small trainable matrices to frozen layers — efficient and popular. Instruction tuning: train on instruction-response pairs to follow commands. RLHF: use human feedback to align the model with human preferences — this is how ChatGPT was made helpful. The choice depends on your compute budget and task. Want to explore LoRA?"},

    {"input": "Can you explain more about tokenization?",
     "output": "Of course! Modern LLMs use Byte Pair Encoding (BPE) tokenization. It starts with individual characters, then merges the most frequent pairs iteratively. 'unhappiness' might become ['un', 'happiness'] or ['un', 'happy', 'ness']. GPT-4 has a vocabulary of ~100k tokens. Why does this matter? More tokens = higher cost and slower generation. Efficient tokenization is crucial for long documents. Want to see how to count tokens?"},

    # Practical ML
    {"input": "Can you explain more about gradient descent?",
     "output": "Sure! There are three variants of gradient descent. Batch GD: use all training data per step — stable but slow. Stochastic GD (SGD): use one sample per step — fast but noisy. Mini-batch GD: use small batches (32-256 samples) — best of both worlds, most commonly used. The learning rate is crucial: too high causes divergence, too low causes slow convergence. Adam optimizer adapts the learning rate automatically. Want to understand Adam?"},

    {"input": "Tell me more about loss functions.",
     "output": "Absolutely! Different tasks need different loss functions. For regression: Mean Squared Error (MSE) = average of (prediction - target)². For binary classification: Binary Cross-Entropy = -[y×log(p) + (1-y)×log(1-p)]. For multi-class: Categorical Cross-Entropy. For object detection: combination of localization and classification losses. Choosing the right loss function is crucial — it defines what 'learning' means for your model. Want to see examples?"},

    {"input": "Can you explain more about cross validation?",
     "output": "Great! The most common type is k-fold cross validation. Split data into k=5 folds. Train on 4 folds, test on 1. Repeat 5 times, each time using a different fold as test. Average the 5 scores. This gives a more reliable estimate than a single train-test split. Stratified k-fold ensures each fold has the same class distribution — important for imbalanced datasets. Want to see how to implement it?"},

    {"input": "Tell me more about decision trees.",
     "output": "Sure! A decision tree splits data by choosing the feature and threshold that best separates the classes. The splitting criterion is usually Gini impurity or Information Gain. It keeps splitting until a stopping condition: max depth reached, minimum samples per leaf, or pure node. Advantages: interpretable, handles mixed data types, no scaling needed. Disadvantage: prone to overfitting. That's why Random Forest uses many trees together. Want to understand tree pruning?"},

    {"input": "Can you explain more about random forest?",
     "output": "Of course! Random Forest uses two sources of randomness. Bootstrap sampling: each tree trains on a random subset of the data (with replacement). Feature randomness: at each split, only a random subset of features is considered. This ensures diversity among trees. Final prediction: majority vote for classification, average for regression. It's one of the most reliable algorithms — works well out of the box with minimal tuning. Want to compare it with gradient boosting?"},

    # Advanced topics
    {"input": "Tell me more about transfer learning.",
     "output": "Absolutely! Transfer learning works because early layers learn universal features — edges, textures, basic patterns — that are useful across tasks. You freeze these layers and only train the final layers on your specific task. ImageNet-pretrained models work for medical imaging, satellite images, even non-visual tasks. In NLP, BERT and GPT pretrained on web text transfer to sentiment analysis, question answering, summarization. Want to see a practical example?"},

    {"input": "Can you explain more about reinforcement learning?",
     "output": "Great! RL has four key components. Agent: the learner and decision maker. Environment: what the agent interacts with. State: current situation. Reward: feedback signal. The agent learns a policy — a mapping from states to actions — that maximizes cumulative reward. Q-learning and Policy Gradient are the two main algorithm families. DeepMind's AlphaGo combined RL with deep learning to beat world champions. Want to understand Q-learning?"},

    {"input": "Tell me more about GANs.",
     "output": "Sure! Training a GAN is like a game between two players. The Generator tries to fool the Discriminator by creating realistic fake data. The Discriminator tries to correctly identify real vs fake. They improve together until the Generator produces data indistinguishable from real. Applications: image synthesis, style transfer, data augmentation, deepfakes. The training can be unstable — mode collapse is a common problem where the Generator produces only one type of output. Want to understand how to stabilize training?"},

    {"input": "Can you explain more about RLHF?",
     "output": "Of course! RLHF has three stages. Stage 1: supervised fine-tuning — train on human-written examples of good behavior. Stage 2: reward model training — humans rank model outputs, train a model to predict human preference scores. Stage 3: RL optimization — use PPO algorithm to optimize the LLM to maximize the reward model score. This process aligns the model with human values and preferences. It's expensive but very effective. Want to understand PPO?"},

    {"input": "Tell me more about embeddings.",
     "output": "Absolutely! Embeddings are dense vector representations — typically 768 to 4096 dimensions. Similar concepts cluster together in this high-dimensional space. You can do arithmetic: king - man + woman ≈ queen. They're created by training a model on a large corpus. Applications: semantic search, recommendation systems, RAG, clustering documents. Cosine similarity measures how similar two embeddings are — values close to 1 mean very similar. Want to see how to use embeddings in practice?"},

    {"input": "Can you explain more about RAG?",
     "output": "Great! RAG works in three steps. Step 1: indexing — chunk documents, create embeddings, store in vector database. Step 2: retrieval — embed the user query, find most similar chunks using cosine similarity. Step 3: generation — pass retrieved chunks as context to the LLM, ask it to answer based on them. This grounds the model in real documents and reduces hallucination. Tools like LangChain and LlamaIndex make this easy to implement. Want to see the full pipeline?"},

    # Evaluation
    {"input": "Tell me more about precision and recall.",
     "output": "Sure! Let's make it concrete with spam detection. Precision = TP / (TP + FP) — of all emails flagged as spam, how many really were spam? High precision = few false alarms. Recall = TP / (TP + FN) — of all actual spam emails, how many did we catch? High recall = few missed spams. F1 score = 2 × (precision × recall) / (precision + recall) — balances both. In medical diagnosis, recall is often more important — missing a disease is worse than a false alarm. Does that clarify the tradeoff?"},

    {"input": "Can you explain more about the confusion matrix?",
     "output": "Of course! A confusion matrix for binary classification has 4 cells. True Positive (TP): predicted positive, actually positive. True Negative (TN): predicted negative, actually negative. False Positive (FP): predicted positive, actually negative — Type I error. False Negative (FN): predicted negative, actually positive — Type II error. Accuracy = (TP+TN)/(TP+TN+FP+FN). But accuracy is misleading on imbalanced datasets — use precision, recall, and F1 instead. Want to see an example calculation?"},

    {"input": "Tell me more about normalization.",
     "output": "Absolutely! There are two main types. Min-Max normalization scales to [0,1]: x_norm = (x - min) / (max - min). Standardization (Z-score) scales to mean=0, std=1: x_std = (x - mean) / std. Use Min-Max when you need bounded values. Use standardization when your data follows a normal distribution or when using algorithms sensitive to outliers. Most deep learning uses batch normalization — normalizing activations within each layer during training. Does that help?"},

    {"input": "Can you explain more about data preprocessing?",
     "output": "Sure! The main steps are: Handle missing values — delete rows, fill with mean/median, or use model-based imputation. Handle outliers — detect with IQR or Z-score, then remove or cap them. Encode categorical variables — one-hot encoding for nominal, label encoding for ordinal. Scale numerical features — normalization or standardization. Feature engineering — create new meaningful features. Split data — train/validation/test before any preprocessing to avoid data leakage. Clean data is everything. Want to go through a specific step?"},

    # Ethics and concepts
    {"input": "Tell me more about AI explainability.",
     "output": "Great! There are two main approaches. Model-specific methods: decision tree rules, linear regression coefficients — interpretable by design. Model-agnostic methods work on any model. LIME: perturbs inputs and fits a local linear model to approximate the black box. SHAP: uses game theory to assign each feature a contribution value. Both answer 'why did the model predict this?'. Explainability is crucial in healthcare, finance, and legal applications where decisions must be justified. Want to explore SHAP in detail?"},

    {"input": "Can you explain more about bias in machine learning?",
     "output": "Of course! Bias enters ML systems in several ways. Data bias: training data doesn't represent the real population. Label bias: human annotators bring their own prejudices. Feedback loops: biased predictions create biased future data. Measurement bias: what you measure doesn't capture what you care about. Detection methods: fairness metrics like demographic parity, equal opportunity. Mitigation: diverse training data, adversarial debiasing, fairness constraints. This is an active research area with no perfect solutions. Want to explore fairness metrics?"},

    {"input": "Tell me more about hyperparameters.",
     "output": "Absolutely! Common hyperparameters include: learning rate (most important — try 1e-3, 1e-4, 1e-5), batch size (32, 64, 128), number of layers and neurons, dropout rate (0.1 to 0.5), weight decay for regularization. Tuning methods: manual search (intuition-based), grid search (exhaustive but expensive), random search (surprisingly effective), Bayesian optimization (smart search). Start with learning rate — it has the biggest impact. A good rule: if loss is NaN, reduce learning rate by 10x. Want to see a systematic approach?"},

    {"input": "Can you explain more about dropout?",
     "output": "Sure! During training, dropout randomly sets a fraction p of neurons to zero at each forward pass. This forces the network to learn redundant representations — no single neuron can be relied upon. At inference time, all neurons are active but outputs are scaled by (1-p). Typical values: p=0.1 to 0.3 for convolutional layers, p=0.5 for fully connected layers. It's equivalent to training an ensemble of 2^n different networks. Introduced by Hinton in 2012, it's still widely used today. Does that clarify it?"},

    {"input": "Tell me more about batch normalization.",
     "output": "Of course! Batch norm normalizes activations within each mini-batch: subtract mean, divide by std, then scale and shift with learnable parameters γ and β. Benefits: allows higher learning rates, reduces sensitivity to weight initialization, acts as regularization. Where to put it: typically after the linear layer and before the activation function. At inference, it uses running statistics computed during training. Layer normalization is a variant used in Transformers — it normalizes across features instead of batch. Want to understand when to use each?"},

    {"input": "Can you explain more about the vanishing gradient problem?",
     "output": "Absolutely! In deep networks, gradients are multiplied at each layer during backpropagation. If activations like sigmoid output values in (0,1), their derivatives are < 0.25. Multiply 100 of these together and the gradient becomes essentially zero — early layers learn nothing. Solutions: ReLU activation (gradient is 1 for positive inputs), batch normalization (keeps activations in a good range), residual connections (gradients can flow directly through skip connections — this is how ResNet trains 100+ layer networks). Want to understand residual connections?"},

    {"input": "Tell me more about learning rate.",
     "output": "Great! The learning rate is the most important hyperparameter. Too high: loss oscillates or diverges. Too low: training is extremely slow, may get stuck. Best practice: use a learning rate scheduler. Warmup: start low, ramp up for first few epochs. Cosine annealing: smoothly decrease from max to min. Cyclical LR: oscillate between min and max — helps escape local minima. Adam optimizer adapts the learning rate per parameter automatically — that's why it's the default choice. A good starting point: lr=3e-4 with Adam. Want to see how to implement scheduling?"},

    {"input": "Can you explain more about early stopping?",
     "output": "Sure! Early stopping monitors a validation metric (usually validation loss) after each epoch. It keeps track of the best model seen so far. If the metric doesn't improve for 'patience' epochs (typically 5-10), training stops and the best model is restored. Benefits: prevents overfitting, saves compute, automatically finds the right number of epochs. Important: always monitor validation loss, not training loss — training loss always decreases but validation loss may start increasing. It's one of the most effective regularization techniques. Does that clarify it?"},

    {"input": "Tell me more about word embeddings.",
     "output": "Absolutely! Word2Vec was the breakthrough — trained by predicting context words (CBOW) or predicting a word from context (Skip-gram). Similar words end up close in vector space. GloVe uses global co-occurrence statistics instead. FastText extends Word2Vec with subword information — handles unknown words and morphology better. Modern LLMs use contextual embeddings — the same word has different vectors depending on context. 'Bank' in 'river bank' vs 'money bank' get different embeddings. This is the key advance of BERT and GPT over Word2Vec. Want to compare them?"},
]

# Ajouter au dataset existant
follow_up_df = pd.DataFrame(follow_up_data)
df = pd.concat([df, follow_up_df], ignore_index=True)
print(f"Total examples: {len(df)}")
# Out:
# Total examples: 99

# %%
nn_fix = [
    {"input": "What is a neural network?",
     "output": "Nice question! A neural network is inspired by the human brain. It has neurons organized in layers — input layer receives raw data, hidden layers extract patterns, output layer makes predictions. Each neuron applies weights, bias, and an activation function. Think of it as a factory with multiple departments working together. Want to zoom into one layer?"},

    {"input": "What is a neural network?",
     "output": "Good question! A neural network consists of layers of connected neurons. The first layer takes your input data. The middle hidden layers learn increasingly complex features. The final layer outputs the prediction. It's called 'deep' learning when there are many hidden layers. Does that make sense? Want to see how training works?"},

    {"input": "What is a neural network?",
     "output": "Great question! Think of a neural network like the human brain — neurons connected in layers. Layer 1: receives raw data like pixels or words. Layer 2-N: transforms data into useful patterns. Last layer: outputs a prediction. The connections between neurons have weights that are learned during training. Want to understand backpropagation?"},
]

nn_df = pd.DataFrame(nn_fix)
df = pd.concat([df, nn_df], ignore_index=True)
print(f"Total: {len(df)}")
# Out:
# Total: 102

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

model_name = "gpt2-medium"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = GPT2LMHeadModel.from_pretrained(model_name)
device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

print("Model loaded on:", device)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# ...

# %%
# Vérification dataset
print(f"Total exemples: {len(df)}")
print(f"Doublons: {df.duplicated().sum()}")
print(f"Valeurs manquantes:\n{df.isnull().sum()}")
print(f"\nLongueur moyenne input: {df['input'].str.len().mean():.0f} chars")
print(f"Longueur moyenne output: {df['output'].str.len().mean():.0f} chars")
print(f"Output le plus court: {df['output'].str.len().min()} chars")
print(f"Output le plus long: {df['output'].str.len().max()} chars")
# Out:
# Total exemples: 102
# Doublons: 2
# Valeurs manquantes:
# input     0
# output    0
# dtype: int64
#
# Longueur moyenne input: 33 chars
# Longueur moyenne output: 349 chars
# Output le plus court: 215 chars
# Output le plus long: 567 chars

# %%
df = df.drop_duplicates().reset_index(drop=True)
print(f"Total après nettoyage: {len(df)}")
# Out:
# Total après nettoyage: 100

# %%
test_questions = [
    "What is machine learning?",
    "Explain overfitting simply.",
    "What is a neural network?",
    "Tell me more about word embeddings."]

def ask_before(question):
    torch.manual_seed(42)
    prompt = f"Question: {question}\nAnswer:"
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(
        **inputs,
        max_new_tokens=100,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=2.0,
        pad_token_id=tokenizer.eos_token_id
    )
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return decoded.split("Answer:")[-1].strip()

print("BEFORE FINE-TUNING")
print("=" * 60)
for q in test_questions:
    print(f"\nQ: {q}")
    print(f"A:\n{ask_before(q)}")
    print("-" * 40)
# Out:
# BEFORE FINE-TUNING
# ...
#
# Q: What is machine learning?
# A:
# Machine Learning refers to the process of combining different data sets, such as images and speech. This can be done by using various methods like statistical analysis or supervised models (a combination that includes many independent variables). To learn a skill from any single image you need only have some training set with each value associated for it in order; otherwise one cannot train this ability on an unstructured dataset because there are too few values available at once! However, if we could combine all these information into another trained model
# ----------------------------------------
#
# Q: Explain overfitting simply.
# A:
# ...

# %%
from torch.optim import AdamW
import copy


# Préparer les textes
def format_text(row):
    return f"Question: {row['input']}\nAnswer: {row['output']}{tokenizer.eos_token}"

texts = [format_text(df.iloc[i]) for i in range(len(df))]

# Tokenizer
encodings = tokenizer(
    texts,
    truncation=True,
    max_length=128,
    padding="max_length",
    return_tensors="pt"
)

input_ids = encodings.input_ids.to(device)
attention_mask = encodings.attention_mask.to(device)

# Training loop
optimizer = AdamW(model.parameters(),
                  lr=1e-4,
                  weight_decay=0.01)
batch_size=4

best_loss = float('inf')
patience = 5
patience_counter = 0
best_state = None

# Vider le GPU
torch.cuda.empty_cache()
model.train()
for epoch in range(30):
    total_loss = 0
    for i in range(0, len(input_ids), batch_size):
        batch_ids = input_ids[i:i+batch_size]
        batch_mask = attention_mask[i:i+batch_size]
        optimizer.zero_grad()
        labels = batch_ids.clone()
        labels[batch_mask == 0] = -100

        outputs = model(
         input_ids=batch_ids,
         attention_mask=batch_mask,
         labels=labels
        )
        loss = outputs.loss
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1} | Loss: {total_loss:.4f}")

print("finetune done ✓")
# Out:
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.

# %%
model.eval()

def ask_after(question):
    torch.manual_seed(42)
    prompt = f"Question: {question}\nAnswer:"
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(
        **inputs,
        max_new_tokens=80,
        do_sample=False,
        temperature=0.3,
        top_p=0.9,
        repetition_penalty=1.0,
        pad_token_id=tokenizer.eos_token_id
    )
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return decoded.split("Answer:")[-1].strip()

print("AFTER FINE-TUNING")
print("=" * 60)
for q in test_questions:
    print(f"\nQ: {q}")
    print(f"A:\n{ask_after(q)}")
    print("-" * 40)

# %%
# !pip install gradio -q

# %%
import gradio as gr

last_topic = {"topic": "", "last_answer": ""}

def chat(question, history):
    if not question.strip():
        return history, ""

    follow_ups = ["yes", "oui", "sure", "ok", "go ahead", "please", "yes please", "why not", "yeah", "tell me more"]

    if question.lower().strip() in follow_ups and last_topic["topic"]:
        # Construire un prompt avec contexte
        full_prompt = f"""Question: {last_topic['topic']}
Answer: {last_topic['last_answer']}
Student: Can you explain more with a different example?
Tutor:"""
    else:
        full_prompt = f"Question: {question}\nAnswer:"
        last_topic["topic"] = question

    torch.manual_seed(42)
    inputs = tokenizer(full_prompt, return_tensors="pt", truncation=True, max_length=300).to(device)
    outputs = model.generate(
        **inputs,
        max_new_tokens=120,
        do_sample=True,
        temperature=0.5,
        top_p=0.9,
        repetition_penalty=1.3,
        pad_token_id=tokenizer.eos_token_id
    )
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)

    if question.lower().strip() in follow_ups:
        response = decoded.split("Tutor:")[-1].strip()
    else:
        response = decoded.split("Answer:")[-1].strip()

    last_topic["last_answer"] = response
    history.append((question, response))
    return history, ""

with gr.Blocks(
    theme=gr.themes.Soft(),
    css="""
    .gradio-container {
        max-width: 800px !important;
        margin: auto !important;
    }
    .chat-header {
        text-align: center;
        padding: 20px;
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        border-radius: 12px;
        margin-bottom: 20px;
        color: white;
    }
    footer {display: none !important}
    """
) as demo:

    gr.HTML("""
    <div class="chat-header">
        <h1>🎓 StudyMate</h1>
        <p>Your patient AI tutor for Machine Learning, Deep Learning & LLMs</p>
    </div>
    """)

    chatbot = gr.Chatbot(
        label="Conversation",
        height=400,
        bubble_full_width=False,
        avatar_images=("👤", "🎓")
    )

    with gr.Row():
        question_input = gr.Textbox(
            placeholder="Ask me anything about AI, ML, Deep Learning...",
            label="",
            scale=4,
            lines=1
        )
        send_btn = gr.Button("Send 🚀", scale=1, variant="primary")

    gr.Examples(
        examples=[
            "What is machine learning?",
            "Explain overfitting simply.",
            "What is a neural network?",
            "What is gradient descent?",
            "What is fine-tuning?"
        ],
        inputs=question_input,
        label="Try these examples"
    )

    history_state = gr.State([])

    send_btn.click(
        fn=chat,
        inputs=[question_input, history_state],
        outputs=[chatbot, question_input]
    )

    question_input.submit(
        fn=chat,
        inputs=[question_input, history_state],
        outputs=[chatbot, question_input]
    )

demo.launch(share=True)

# %%
model.save_pretrained("./studymate_gpt2")
tokenizer.save_pretrained("./studymate_gpt2")
print("Model saved ✓")

# %%
# !pip install huggingface_hub -q

# %%
from huggingface_hub import HfApi, login

# Connecte toi avec ton token HuggingFace
login("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")  # ← va te demander ton token

# %%
from huggingface_hub import HfApi

api = HfApi()

# Créer le repo
api.create_repo(repo_id="studymate-gpt2", exist_ok=True)

# Upload le modèle
api.upload_folder(
    folder_path="./studymate_gpt2",
    repo_id="yasminesd/studymate-gpt2",  # ← remplace ton_username
    repo_type="model"
)

print("Model uploaded ✓")
